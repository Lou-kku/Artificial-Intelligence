# %% [markdown]
# # Diabetes 분류문제를 회귀문제로 변형 후 해결

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split


df = pd.read_csv("C:/Users/Lenovo/Desktop/week3/diabetes.csv", index_col=0)
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# 1                               0.351   31        0
# 8                               0.672   32        1
# 1                               0.167   21        0
# 0                               2.288   33        1
# ...                               ...  ...      ...
# 10                              0.171   63        0
# 2                               0.340   27        0
# 5                               0.245   30        0
# 1                               0.349   47        1
# 1                               0.315   23        0
#
# [768 rows x 8 columns]

# %% [markdown]
# ## 회귀문제로 바꾸기위해 Outcome을 제거

# %%
df = df.drop(columns=['Outcome'])
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age
# Pregnancies
# 6                               0.627   50
# 1                               0.351   31
# 8                               0.672   32
# 1                               0.167   21
# 0                               2.288   33
# ...                               ...  ...
# 10                              0.171   63
# 2                               0.340   27
# 5                               0.245   30
# 1                               0.349   47
# 1                               0.315   23
#
# [768 rows x 7 columns]

# %% [markdown]
# ## BMI를 예측하는 문제

# %%
X = df.drop('BMI',axis=1)
X.head()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin  \
# Pregnancies
# 6                148             72             35        0
# 1                 85             66             29        0
# 8                183             64              0        0
# 1                 89             66             23       94
# 0                137             40             35      168
#
#              DiabetesPedigreeFunction  Age
# Pregnancies
# 6                               0.627   50
# 1                               0.351   31
# 8                               0.672   32
# 1                               0.167   21
# 0                               2.288   33

# %%
y = df['BMI']
y.head()
# Out:
# Pregnancies
# 6    33.6
# 1    26.6
# 8    23.3
# 1    28.1
# 0    43.1
# Name: BMI, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, shuffle=True, random_state=12)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (614, 6) (614,)
# (154, 6) (154,)

# %%
#라이브러리 불러오기
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

#선형 회귀 모델 생성 및 학습
model = LinearRegression()
model.fit(X_train, y_train)

#테스트 데이터로 예측
ly_preds = model.predict(X_test)

#평균제곱오차(MSE)계산
#sklearn라이브러리 사용
print('평균제곱근오차', mean_squared_error(ly_preds, y_test))

#numpy 활용 
def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ly_preds, y_test))

#for루프 활용
def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 50.97695632055755
# 평균제곱근오차 50.97695632055755
# 평균제곱근오차 50.97695632055754

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 105.43220779220778

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 43.90664507792209

# %%
from sklearn.svm import SVR

model = SVR(kernel='linear')
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 49.3525226147579
