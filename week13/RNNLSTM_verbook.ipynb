# %%
# !pip install finance-datareader

import FinanceDataReader as fdr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.96-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\lenovo\anaconda3\lib\site-packages (from finance-datareader) (4.12.3)
# Requirement already satisfied: lxml in c:\users\lenovo\anaconda3\lib\site-packages (from finance-datareader) (5.2.1)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from finance-datareader) (2.2.2)
# Requirement already satisfied: plotly in c:\users\lenovo\anaconda3\lib\site-packages (from finance-datareader) (5.24.1)
# Requirement already satisfied: requests-file in c:\users\lenovo\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from finance-datareader) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\lib\site-packages (from finance-datareader) (4.66.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.1.0->finance-datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->finance-datareader) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from beautifulsoup4->finance-datareader) (2.5)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from plotly->finance-datareader) (8.2.3)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from plotly->finance-datareader) (24.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm->finance-datareader) (0.4.6)
# Downloading finance_datareader-0.9.96-py3-none-any.whl (48 kB)
# Installing collected packages: finance-datareader
# Successfully installed finance-datareader-0.9.96

# %%
df = pd.read_csv('./AAME.csv')
df
# Out:
#              Date  Open  High   Low  Close  Adj Close  Volume
# 0      1980-03-17  0.00  4.05  3.85   3.85   3.213167   15000
# 1      1980-03-18  0.00  4.00  3.80   3.80   3.171437   10200
# 2      1980-03-19  0.00  4.05  3.85   3.85   3.213167   33500
# 3      1980-03-20  0.00  4.00  3.80   3.80   3.171437    8700
# 4      1980-03-21  0.00  3.95  3.75   3.75   3.129709   12700
# ...           ...   ...   ...   ...    ...        ...     ...
# 10093  2020-03-26  2.29  2.29  2.08   2.28   2.280000    1600
# 10094  2020-03-27  2.25  2.25  2.21   2.25   2.250000     500
# 10095  2020-03-30  2.25  2.25  2.13   2.13   2.130000     400
# 10096  2020-03-31  2.11  2.11  2.11   2.11   2.110000     300
# 10097  2020-04-01  2.11  2.15  2.11   2.15   2.150000     600
#
# [10098 rows x 7 columns]

# %%
openValues = df[['Open']]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))
scaled = scaler.fit_transform(openValues)

# %%
TEST_SIZE = 200
train_data = scaled[:-TEST_SIZE]
test_data = scaled[-TEST_SIZE:]

# %%
def make_sample(data, window):
    train = []
    target = []
    for i in range(len(data)-window):
        train.append(data[i:i+window])
        target.append(data[i+window])
    return np.array(train), np.array(target)

X_train, y_train = make_sample(train_data, 30)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

model = Sequential()
model.add(LSTM(16,
               input_shape=(X_train.shape[1],1),
               activation='tanh',
               return_sequences=False)
         )
model.add(Dense(1))
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(X_train, y_train, epochs = 100, batch_size = 16)
# Out:
# Epoch 1/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0083
# Epoch 2/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0025
# Epoch 3/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0026
# Epoch 4/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0029
# Epoch 5/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 6/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0021
# Epoch 7/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0024
# Epoch 8/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0026
# Epoch 9/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0018
# Epoch 10/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0022
# Epoch 11/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 12/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0025
# Epoch 13/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0023
# Epoch 14/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 15/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0027
# Epoch 16/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0027
# Epoch 17/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0022
# Epoch 18/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0027
# Epoch 19/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0021
# Epoch 20/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0024
# Epoch 21/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0022
# Epoch 22/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 23/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0024
# Epoch 24/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 25/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 26/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0021
# Epoch 27/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0026
# Epoch 28/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0025
# Epoch 29/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0024
# Epoch 30/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0026
# Epoch 31/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0017
# Epoch 32/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 33/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 34/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 35/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0024
# Epoch 36/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 37/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 38/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0028
# Epoch 39/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 40/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 41/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 42/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0019
# Epoch 43/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0023
# Epoch 44/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0026
# Epoch 45/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 46/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0024
# Epoch 47/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0019
# Epoch 48/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 49/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 50/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0019
# Epoch 51/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0020
# Epoch 52/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0020
# Epoch 53/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 54/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0027
# Epoch 55/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 56/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 57/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0021
# Epoch 58/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 59/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0018
# Epoch 60/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0021
# Epoch 61/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0022
# Epoch 62/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0022
# Epoch 63/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0022
# Epoch 64/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 65/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0024
# Epoch 66/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 67/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0024
# Epoch 68/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0027
# Epoch 69/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0022
# Epoch 70/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 71/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0022
# Epoch 72/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0025
# Epoch 73/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 74/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0025
# Epoch 75/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 76/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0022
# Epoch 77/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 78/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0022
# Epoch 79/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0025
# Epoch 80/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 81/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0019
# Epoch 82/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0018
# Epoch 83/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0026
# Epoch 84/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0022
# Epoch 85/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 86/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 87/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 88/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0019
# Epoch 89/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 90/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 91/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 92/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0024
# Epoch 93/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0019
# Epoch 94/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0023
# Epoch 95/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0019
# Epoch 96/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0021
# Epoch 97/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0020
# Epoch 98/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0024
# Epoch 99/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0018
# Epoch 100/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0024

# %%
X_test, y_test = make_sample(test_data,30)
pred = model.predict(X_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,9))
plt.plot(y_test, label='stock price')
plt.plot(pred, label='predicted stock price')
plt.legend()
plt.show()
